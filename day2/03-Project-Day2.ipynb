# %% [markdown]
# # Project - Day 2 -  Processing DAQ data 💽🗂️📡
#
# ## Introduction
#
# Today we will use a simulated DAQ process that will publish messages via NATS with the link to a file that can be downloaded via an HTTP request, as soon as the acquisition machine will store new data.
# You will create a preprocessing program that, upon arrival of a new image, will download it, apply the preprocessing step, and then store it locally in a temporary accumulator.
# Once the accumulator is full, it packs the images and upload them back to your Minio server, in a dedicated bucket.
#
# A schematic representation of the data management you are implementing can is reported below
# ![image.png](attachment:b68fb494-362e-4e8c-a40f-1a75b5060852.png)
#
# But before diving in those tools, let's make sure we are all aligned at the end of the yesterday session.

# %% [markdown]
# ### Preprocessing library
#
# To make the preprocessing happen, we had defined a few Python functions that we want to make available as a library to our Python script.
#
# The functions are:
#  * `get_energy_keV`
# 🏷️, tries to guess the energy of a file from its path (irrelevant for acquired data);
#  * `crop_center` ✂️, crops the center of an image with the energy deposit is located;
#  * `windowing` 🪟, maps the gray scale code actually used in the image datasets in the range [0, 1]
#  * `get_recoil_type` , 🏷️ tries to guess whether an image is due a nuclear or electromagnetic recoil based on the file path (irrelevant for acquired data).

# %%
import numpy as np
from PIL import Image

import warnings

warnings.filterwarnings('ignore')

def get_energy_keV(filename):
    """
    Return the energy in keV as obtained parsing the file path, as a 
    floating point.
    """
    for token in filename.split("/"):
        if "_keV" in token:
            return float(token[:-4])

def crop_center(np_image, half_win=64):
    """Crop a numpy-represented image around its center, the resulting image will be a square of side 2*half_win"""
    low, high = 576//2 - half_win, 576//2 + half_win
    return np_image[low:high, low:high]

def windowing(np_image, x_min, x_max):
    """Crop a numpy-represented image around its center"""
    return np.clip((np_image - x_min)/(x_max - x_min), 0., 1.)

def get_recoil_type(filename):
    """
    Return the strings "nuclear" or "electronic" if the file is 
    located in a subdir of "NR" or "ER", respectively.
    Return None otherwise.
    """
    if "NR" in filename.split("/"):
        return 'nuclear'
    if "ER" in filename.split("/"):
        return "electronic"
    return None

# %% [markdown]
# # Exercise 1 - Check that the DAQ is running ⌛
#
# You DAQ is now running 🚀 isn't it?
#
# Let's check.
#
# Listen for the topic `daq/data/username`(where username the username that you used for logging in in JupyterHub, it can be also retrieved from the environment variable `JUPYTERHUB_USER`)` with a very simple callback, if you don't hear anything for one minute, well, something in your setup is now working...  🪲
# To retrieve environment variable from your python code/notebook:
# ```python
# import os
# username = os.environ['JUPYTERHUB_USER']
# ```
#
#
#
# A super-simple callback you may use to the purpose is simply printing the received messages, such as
# ```python
# def callback(msg):
#     """Callback function for NATS Client"""
#     print (msg.payload)
# ```

# %%
def callback(msg):
    """Callback function for NATS Client"""
    print (msg.payload)

# %%
## Verify DAQ
import os

username=os.environ['JUPYTERHUB_USER']
print(username)

from pynats import NATSClient

NATS_SERVER = "nats://sosc:WrfJg7YK3FzU2ZQh8i23@nats.nats:4222"
# NATS_SERVER = "nats://localhost:4222"
with NATSClient(NATS_SERVER) as client:
    client.connect()
    client.subscribe(subject="daq/data/%s" %(username), callback=callback)
    client.wait(count=3)
# Out:
# lia.lavezzi
# b'{"url": "https://131.154.96.57:9000/cygno-daq/new/cygno-25c8bc2d597eac8f4f5849ff16d3098d.jpg", "time": "2023-10-26 13:23:24.703174", "filename": "new/cygno-25c8bc2d597eac8f4f5849ff16d3098d.jpg"}'
# b'{"url": "https://131.154.96.57:9000/cygno-daq/new/cygno-15f080843950af9e664eb49b62a6568b.jpg", "time": "2023-10-26 13:23:24.749772", "filename": "new/cygno-15f080843950af9e664eb49b62a6568b.jpg"}'
# b'{"url": "https://131.154.96.57:9000/cygno-daq/new/cygno-b38ff61043c0663f0f53fca4c90a48f8.jpg", "time": "2023-10-26 13:23:25.037437", "filename": "new/cygno-b38ff61043c0663f0f53fca4c90a48f8.jpg"}'

# %% [markdown]
# ## Exercise 2 - Download a single image via HTTP  ⌛⌛
#
# If you are down here, you have a functioning DAQ involving three services: a simulator, a messaging server based on NATS and a storage server based on Minio!
#
# Congrats! 👏👏👏
#
# Now it's time to do something of the message injected through NATS.
#
# The first thing we need is to digest the message and to extract the information it carries, notably:
#  * the timestamp of the recorded interaction (the ***metadata***)
#  * the acquired image of the interaction (the ***data***)
#
# Now, the NATS `payload` is a raw byte stream, to make it a string we need to agree with the sender on an encoding. Most encoding are equal for the alphanumeric characters, but you might be unable to send nice emojis (and most importanly accented letters) if do not agree on an encoding before starting a communication.
#
# Maybe luckily, our NATS injector is not interested in submitting emojis 😢, so any encoding is ok, but still you need to choose one.
#
# Usually people pick `ascii` if they are sure special characters are not there, or `utf-8` if living in a standard Linux world, or `latin-1` if they need to support Windows.
#
#
# Once you have a string, you can decode it using the `json` module of the Python Standard Libraries, to extract the url and timestamp fields.
#
# The `unpack_payload` function defined here implements these steps for you.

# %%
import json

def unpack_payload (msg):
    """Unpack the payload returning the timestamp and the url, separately."""
    ## Convert the message data in a string, assuming utf-8 encoding
    payload_string = str(msg.payload, 'utf-8')
    ## Convert the payload to a dictionary using the json module
    payload_dict = json.loads(payload_string)
    ## Obtain the url and the timestamp from the dictionary
    url = payload_dict['url']
    timestamp = payload_dict['time']

    ## Return the timestamp and the url
    return timestamp, url

# %% [markdown]
# You can now plug the `unpack_payload` function in your `callback` and print separately the timestamp and presigned url.

# %%
def callback(msg):
    """Callback function for NATS Client"""
    print (msg.payload)
    global glo_timestamp
    global glo_url 
    glo_timestamp,glo_url = unpack_payload (msg)
    glo_timestamp_list.append(glo_timestamp)
    glo_url_list.append(glo_url)

# %% [markdown]
# ### Download the image via HTTP
#
# Using the `requests` module and its `get` function, obtain the image from the presigned url as returned by `unpack_payload`.
#
# You may want to review:
#  * the [function `requests.get`](https://requests.readthedocs.io/en/latest/user/quickstart/)
#  * the standard way of managing error codes with the [method `raise_for_status`](https://requests.readthedocs.io/en/latest/api/#requests.Response.raise_for_status)
#  * the [`io` module](https://docs.python.org/3/library/io.html) and its [BytesIO](https://docs.python.org/3/library/io.html#io.BytesIO) mimicking file access to memory-located resources
#  * the [basics of `pillow`](https://pillow.readthedocs.io/en/stable/reference/Image.html#) and in particular the [function `PIL.Image.open`](https://pillow.readthedocs.io/en/stable/reference/Image.html#PIL.Image.open) for loading images from standard formats (such as JPG)
#
#
# You next cell should look like:
#
# ```python
# ## ... your imports here ...
#
# def download_image(url):
#   ## your request
#   ## your conversion of the response to PIL.Image
#   return image
# ```

# %%
def download_image(url):
    import requests
    import io
    import PIL
    ## your request
    ## your conversion of the response to PIL.Image
    response = requests.get(url, verify=False)
    ## Print the status code and the reason
    print(f"Status code: {response.status_code} [{response.reason}]")
    ## Convert the content into an in-memory binary file
    figure = io.BytesIO(response.content)
    ## and finally loads that in-memory binary file as an image using pillow
    image=PIL.Image.open(figure)
    return image

# %%
## get image
import os

username=os.environ['JUPYTERHUB_USER']
print(username)

#from pynats import NATSClient

#NATS_SERVER = "nats://sosc:WrfJg7YK3FzU2ZQh8i23@nats.nats:4222"

glo_timestamp_list=[]
glo_url_list=[]
with NATSClient(NATS_SERVER) as client:
    client.connect()
    client.subscribe(subject="daq/data/%s" %(username), callback=callback)
    client.wait(count=3)

print("filling image list")
image_list=[]
for url in glo_url_list:
    image=download_image(url)    
    image_list.append(image)
print("done")
# Out:
# lia.lavezzi
# b'{"url": "https://131.154.96.57:9000/cygno-daq/new/cygno-d8a0e82c440fd401af805c0886378c09.jpg", "time": "2023-10-26 13:23:34.190443", "filename": "new/cygno-d8a0e82c440fd401af805c0886378c09.jpg"}'
# b'{"url": "https://131.154.96.57:9000/cygno-daq/new/cygno-453c7b9775b9879714df705ad925f0e7.jpg", "time": "2023-10-26 13:23:34.418901", "filename": "new/cygno-453c7b9775b9879714df705ad925f0e7.jpg"}'
# b'{"url": "https://131.154.96.57:9000/cygno-daq/new/cygno-1d5501c41bfe153952e2dad8bbded54b.jpg", "time": "2023-10-26 13:23:34.436124", "filename": "new/cygno-1d5501c41bfe153952e2dad8bbded54b.jpg"}'
# filling image list
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# done

# %% [markdown]
# ### Adapt your `callback` function to display the image instead of its url
#
# Now you have all the pieces to redefine your `callback (msg)` function to download the image from the `url` you unpacked from NATS and to display it in the Jupyter notebook with the `display(image)` function.
#
# Wait for another hit and check your callback is functioning. You should see the

# %%
## get image
import os

username=os.environ['JUPYTERHUB_USER']

print(username)

NATS_SERVER = "nats://sosc:WrfJg7YK3FzU2ZQh8i23@nats.nats:4222"

## Solution
from pynats import NATSClient

def callback(msg):
    """Callback function from NATS Client"""
    timestamp, url = unpack_payload(msg)
    img = download_image (url)
    display(img)

with NATSClient(NATS_SERVER) as client:
    client.subscribe(subject="daq/data/%s" %(username), callback=callback)
    
    client.wait(count=2)
# Out:
# lia.lavezzi
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>

# %% [markdown]
# ## Exercise 3 - Download and Upload to your Minio  ⌛⌛⌛⌛
#
# Well done! You are downloading data based on the messages obtained from NATS.
#
# Now you have to walk the opposite path and upload some processed file to Minio.
#
# As you have learned during the morning sessions, **object storage is great for large files accessed as a whole**. Using object storage for a myriad of tiny  images is not exactly what it was designed for.
#
# A step towards improvement is to aggregate the images in chunks or batches and then re-upload the datasets to Minio in one go.
#
# There are better and more robust ways of implementing such an aggregation, but here we try to be minimal to focus on data management aspects, so:
#  * define two global vatiables as empty lists, one will accumulate the received images, one will accumulate the timestamps
#  * define a function taking as a input the decoded `PIL.Image` and its associated timestamp; converting them to numpy data formats; and appending to them to their lists
#
# > **Important!** 📆 To store the datetime in numpy, use [`numpy.datetime64` data format](https://numpy.org/doc/stable/reference/arrays.datetime.html).
#
# For example
# ```python
# ## define global lists
# list_of_images = list()
# ## same for timestamps
#
# def convert_and_accumulate_to_global_lists(timestamp, image):
#   np_image = ## convert image to numpy array
#   list_of_images.append ( np_image )
#   ## same thing for the timestamps
# ```

# %%
def convert_and_accumulate_to_global_lists(timestamp, image):
    """Accumulate the downloaded images and timestamps to global lists."""
    glo_timestamp_list.append(np.datetime64(timestamp))
    glo_image_list.append(np.asarray(image))

# %%
def callback(msg):
    """Callback function from NATS Client"""
    timestamp, url = unpack_payload(msg)
    img = download_image (url)
    display(img)
    convert_and_accumulate_to_global_lists(timestamp,img)

# %%
## get image
import os

username=os.environ['JUPYTERHUB_USER']
print(username)

NATS_SERVER = "nats://sosc:WrfJg7YK3FzU2ZQh8i23@nats.nats:4222"

## Solution
from pynats import NATSClient

glo_timestamp_list=[]
glo_image_list=[]
    
with NATSClient(NATS_SERVER) as client:
    client.subscribe(subject="daq/data/%s" %(username), callback=callback)
    client.wait(count=3)
# Out:
# lia.lavezzi
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>

# %% [markdown]
# ### Upload to Minio the lists
#
# Define another function, say `upload_global_lists_to_minio` taking as an input:
#  * a maximal number `n_items` of events to pack and upload
#  * the url of the `minio_server`
#  * the user name `minio_user` of the Minio server
#  * the password `minio_password` of the Minio server
#  * the name of the bucket, `minio_bucket`, where to store the aggregated datasets
#
# When invoked, this function will:
#  1. Check whether the number of enqueued images (or timestamps) is above the threshold and returns without doing anything else, otherwise.
#  2. Pack the global lists, `list_of_images` and `list_of_timestamps` into two arrays and store them to a temporary file using the [function `np.savez`](https://numpy.org/doc/stable/reference/generated/numpy.savez.html).
#  3. Establish a connection to Minio based on the url and credentials passed as arguments
#  4. Upload the file temporary file with `minio.fput_object` using a filename containing the first or the latest timestamp (enabling name-based ordering).
#  5. Clear the global lists (have a look to the [function `list.clear`](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists)).
#
# > **Hint.** The object name might be defined for example as
# > ```python
# >     object_name = f'data-chunk-{list_of_timestamps[-1]}.npz'
# > ```

# %%
import boto3

import hashlib
import os

username2='lia-2elavezzi'
hash_object = hashlib.md5(f'{username2}'.encode())
password = hash_object.hexdigest()
print(f"Username2: {username2}\npassword: {password}")

def upload_global_lists_to_minio(
        minio_folder = "cygno-store",
        n_items=10,
        minio_server="https://minio.131.154.99.220.myip.cloud.infn.it",
        minio_user=username2,
        minio_akey=password,
    ):
    """If the accumulation lists are longer than n_items, packs them in a zip file and upload it Minio"""
    if len(glo_image_list) < n_items:
        return 

    print("UPLOAD",minio_user,minio_akey)
    ## Ensure the bucket exists
    s3 = boto3.resource(
        's3',
        endpoint_url=minio_server,
        aws_access_key_id=minio_user,
        aws_secret_access_key=minio_akey
    )

    ## Packs the items to a temporary file
    np.savez("/tmp/cygno.npz",
        image=np.array(glo_image_list),
        tstamp=np.array(glo_timestamp_list),
    )
        
    ## Upload to minio the temporary file
    object_name = f'{minio_folder}/data-chunk-{glo_timestamp_list[-1]}.npz'

    with open('/tmp/cygno.npz', 'rb') as data:
        s3.Bucket(username2).put_object(Key=object_name, Body=data)
    print (f"Uploaded {object_name}")  ## <<-- debugging 
        
    ## Reinitialize the accumulation lists
    glo_image_list.clear()
    glo_timestamp_list.clear()
# Out:
# Username2: lia-2elavezzi
# password: 957ba464403d7d86aa1e6d6b7c289da7

# %% [markdown]
# Then update your callback to execute the functions `convert_and_accumulate_to_global_lists` and `upload_global_lists_to_minio`
# and test it with `n_test=3`.
#
# > **Hint!** Clearly, you will need to wait at least for `n_test` hits before seeing the upload part running. Consider using a small `n_test` for debugging purpose.

# %%
def callback(msg):
    """Callback function from NATS Client"""
    timestamp, url = unpack_payload(msg)
    img = download_image (url)
    display(img)
    convert_and_accumulate_to_global_lists(timestamp,img)
    upload_global_lists_to_minio(n_items=3)

# %%
## get image
import os

username=os.environ['JUPYTERHUB_USER']
#username="lia-2elavezzi"
print(username)

NATS_SERVER = "nats://sosc:WrfJg7YK3FzU2ZQh8i23@nats.nats:4222"

## Solution
from pynats import NATSClient

glo_timestamp_list=[]
glo_image_list=[]
    
with NATSClient(NATS_SERVER) as client:
    client.subscribe(subject="daq/data/%s" %(username), callback=callback)
    client.wait(count=3)
# Out:
# lia.lavezzi
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded cygno-store/data-chunk-2023-10-25T11:45:25.203970.npz

# %% [markdown]
# ### Test it
#
# You can use the following function to list the objects in your bucket and check the size and the datatype of the data chunks.

# %%
import hashlib
import os
#username = os.environ['JUPYTERHUB_USER']
username2='lia-2elavezzi'
hash_object = hashlib.md5(f'{username2}'.encode())
password = hash_object.hexdigest()
print(f"Username: {username2}\npassword: {password}")

import boto3
import json

s3client = boto3.client('s3',
    aws_access_key_id=username2,
    aws_secret_access_key=password,
    endpoint_url="https://minio.131.154.99.220.myip.cloud.infn.it",
    region_name='default',)

bucket_name = 'lia-2elavezzi'
resp = s3client.list_objects(Bucket=bucket_name)
for object in resp['Contents']:
        print("object:",object['Key'],"size:",object['Size'])
# Out:
# Username: lia-2elavezzi
# password: 957ba464403d7d86aa1e6d6b7c289da7
# object: 238050313658468910/a853d9dfa43e41bdb4f1d97f952772c4/artifacts/dataset.csv size: 84199
# object: 238050313658468910/cfc68045eadb42ee88d7aa5d5d36181c/artifacts/model/MLmodel size: 1127
# object: 238050313658468910/cfc68045eadb42ee88d7aa5d5d36181c/artifacts/model/conda.yaml size: 263
# object: 238050313658468910/cfc68045eadb42ee88d7aa5d5d36181c/artifacts/model/model.pkl size: 878
# object: 238050313658468910/cfc68045eadb42ee88d7aa5d5d36181c/artifacts/model/python_env.yaml size: 123
# object: 238050313658468910/cfc68045eadb42ee88d7aa5d5d36181c/artifacts/model/requirements.txt size: 133
# object: 238050313658468910/ed82a02e83534cf6b31085c027af07e1/artifacts/test.csv size: 27724
# object: 238050313658468910/ed82a02e83534cf6b31085c027af07e1/artifacts/train.csv size: 64421
# object: 333999411902639063/877c32d9aab5402182ba9ba073a7509d/artifacts/test.txt size: 12
# object: 731199271821080049/db341db79c814b2eaf257a2521bb24ca/artifacts/model/MLmodel size: 1127
# object: 731199271821080049/db341db79c814b2eaf257a2521bb24ca/artifacts/model/conda.yaml size: 263
# object: 731199271821080049/db341db79c814b2eaf257a2521bb24ca/artifacts/model/model.pkl size: 878
# object: 731199271821080049/db341db79c814b2eaf257a2521bb24ca/artifacts/model/python_env.yaml size: 123
# object: 731199271821080049/db341db79c814b2eaf257a2521bb24ca/artifacts/model/requirements.txt size: 133
# object: 731199271821080049/f689f91a0906499d82c53c5eb0fd2e1e/artifacts/model/MLmodel size: 1127
# object: 731199271821080049/f689f91a0906499d82c53c5eb0fd2e1e/artifacts/model/conda.yaml size: 263
# object: 731199271821080049/f689f91a0906499d82c53c5eb0fd2e1e/artifacts/model/model.pkl size: 878
# object: 731199271821080049/f689f91a0906499d82c53c5eb0fd2e1e/artifacts/model/python_env.yaml size: 123
# object: 731199271821080049/f689f91a0906499d82c53c5eb0fd2e1e/artifacts/model/requirements.txt size: 133
# object: cygno-models/classifier.keras size: 106576
# object: cygno-models/regressor.keras size: 106784
# object: cygno-store/data-chunk-2023-10-24T17:52:02.205337.npz size: 995860
# object: cygno-store/data-chunk-2023-10-24T17:58:34.348730.npz size: 995860
# object: cygno-store/data-chunk-2023-10-25T11:45:25.203970.npz size: 995860
# object: preproc-store/data-chunk-2023-10-25T11:45:37.697048.npz size: 393748
# object: preproc-store/data-chunk-2023-10-25T11:46:30.913785.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:47:07.956963.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:47:47.540019.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:48:30.131985.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:49:07.654883.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:49:51.811545.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:50:34.079853.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:51:15.236414.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:51:49.437809.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:52:27.661773.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:53:06.198418.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:53:43.161865.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:54:25.571100.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:55:07.527547.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:55:49.041008.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:56:26.770677.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:57:09.390502.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:57:47.006852.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:58:32.234176.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:59:08.615231.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T11:59:49.029254.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:00:28.649887.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:01:10.056367.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:01:51.266959.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:02:30.918989.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:03:16.353242.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:03:59.648951.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:04:37.833428.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:05:15.905532.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:05:55.443379.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:06:33.086944.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:07:11.415297.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:07:53.143818.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:08:36.856193.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:09:20.156604.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:10:00.271942.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:10:45.839599.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:11:26.349332.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:12:05.798192.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:12:48.111919.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:13:29.420374.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:14:07.372849.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:14:52.279011.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:15:32.392723.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:16:09.434654.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:16:49.235534.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:17:33.033661.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:18:11.184095.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:18:49.235185.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:19:26.489601.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:20:04.186217.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:20:46.102108.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:21:28.361122.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:22:11.740379.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:22:55.169965.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:23:39.964213.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:24:20.939570.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:25:02.419209.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:25:40.510217.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:26:17.016886.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:26:55.951877.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:27:34.883801.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:28:14.706541.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:28:53.553473.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:29:36.638539.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:30:20.207238.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:31:01.323576.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:31:38.381484.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:32:21.378660.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:33:03.133651.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:33:43.359313.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:34:23.737567.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:35:11.793499.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:35:56.288333.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:36:31.887624.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:37:13.701409.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:37:55.318543.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:38:36.987589.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:39:19.043748.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:40:00.550278.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:40:39.656221.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:41:18.653440.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:42:01.036966.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:42:40.147219.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:43:16.472658.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:44:01.080180.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:44:40.435353.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:45:24.785743.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:46:04.342720.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:46:43.510657.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:47:27.172304.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:48:05.848618.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:48:48.137076.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:49:25.560351.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:50:04.691299.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:50:43.760115.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:51:21.472922.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:52:08.656448.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:52:50.018713.npz size: 26216508
# object: preproc-store/data-chunk-2023-10-25T12:53:29.947811.npz size: 26216508

# %% [markdown]
# ## Exercise 4 - Include the preprocessing step (writing to a different bucket!) ⌛⌛
#
# Define a `preprocessing_step(img)` taking the downloaded `PIL.Image` object as an input and returning a numpy object as obtained applying the *windowing* and *cropping* steps.
#
# > **Hint.** You did something ***very*** similar yesterday. You may want to give a second look to the solutions at the top of this notebook.

# %%
def preprocessing_step(image) :
    np_image = np.array(image)
    np_cropped_image=crop_center(np_image, 64)
    #np_win_image=windowing(np_cropped_image,98,102)
    np_win_image=windowing(np_cropped_image,60,130)
    return np_win_image

# %% [markdown]
# ### Edit and test the `callback` including the `preprocessing_step`
#
# Starting from your previously defined callback, introduce the preprocessing step as needed.
#
# The complete flow will be:
#  1. `unpack_payload` retrieves the timestamp and the url, separately;
#  2. you download the image from its url;
#  3. you preprocess the image;
#  4. you call `convert_and_accumulate_to_global_lists` to process the single image;
#  5. you (maybe) upload the chunk if sufficienly large.
#
#
# > 🚨 **Important!** 🚨
# >
# > Make sure you ***change the bucket used as destination*** or you'll mix
# > preprocessed and raw images in the same bucket.

# %%
def callback(msg):
    """Callback function from NATS Client"""
    timestamp, url = unpack_payload(msg)
    image = download_image (url)
    display(image)
    # preprocess
    pre_proc_image=preprocessing_step(image) 
    convert_and_accumulate_to_global_lists(timestamp,pre_proc_image)
    upload_global_lists_to_minio(minio_user="lia-2elavezzi",minio_folder="preproc-store",n_items=3)

# %%
import os

username=os.environ['JUPYTERHUB_USER']
print(username)

username2='lia-2elavezzi'
hash_object = hashlib.md5(f'{username2}'.encode())
password = hash_object.hexdigest()
print(f"Username2: {username2}\npassword: {password}")

NATS_SERVER = "nats://sosc:WrfJg7YK3FzU2ZQh8i23@nats.nats:4222"

## Solution
from pynats import NATSClient

glo_timestamp_list=[]
glo_image_list=[]
    
with NATSClient(NATS_SERVER) as client:
    client.subscribe(subject="daq/data/%s" %(username), callback=callback)
    client.wait(count=3)
# Out:
# lia.lavezzi
# Username2: lia-2elavezzi
# password: 957ba464403d7d86aa1e6d6b7c289da7
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>
# Status code: 200 [OK]
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576>
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store-new/data-chunk-2023-10-26T13:24:02.554202.npz

# %% [markdown]
# You may want to use the function `check_latest_uploads` discussed above to ensure that your chunk is actually uploaded to Minio and it has expected datatype and shape.

# %%
def check_latest_uploads() :

    import hashlib
    import os
    #username = os.environ['JUPYTERHUB_USER']
    username2='lia-2elavezzi'
    hash_object = hashlib.md5(f'{username2}'.encode())
    password = hash_object.hexdigest()
    print(f"Username: {username2}\npassword: {password}")

    import boto3
    import json
    
    s3client = boto3.client('s3',
        aws_access_key_id=username2,
        aws_secret_access_key=password,
        endpoint_url="https://minio.131.154.99.220.myip.cloud.infn.it",
        region_name='default',)
    
    bucket_name = username2
    resp = s3client.list_objects(Bucket=bucket_name)
    for object in resp['Contents']:
            print("object:",object['Key'],"size:",object['Size'])

# %%
check_latest_uploads()
# Out:
# Username: lia-2elavezzi
# password: 957ba464403d7d86aa1e6d6b7c289da7
# object: cygno-store/data-chunk-2023-10-24T17:52:02.205337.npz size: 995860
# object: cygno-store/data-chunk-2023-10-24T17:58:34.348730.npz size: 995860
# object: cygno-store/data-chunk-2023-10-25T11:45:25.203970.npz size: 995860
# object: preproc-store/data-chunk-2023-10-24T21:59:46.505523.npz size: 393748
# object: preproc-store/data-chunk-2023-10-24T22:05:10.068690.npz size: 393748
# object: preproc-store/data-chunk-2023-10-25T11:45:37.697048.npz size: 393748

# %% [markdown]
# ## Conclusion
#
# Today we discussed the concepts of orchestration and data management.
# We have seen how different containers can exchange information through the network relying on third-party applications such as NATS or Minio.
#
# We have seen how different protocols, such as s3, nats and http can cooperate in a single application to serve different purposes.
#
# Finally, we have deployed the preprocessing step defined yesterday replacing direct access to the local volumes, with network access to Minio, mediated by NATS for distributing messages.
#
# Now let's include more images in our buckets for the next days, specifying 100 round of 200 in the count bucket

# %%
def callback(msg):
    """Callback function from NATS Client"""
    timestamp, url = unpack_payload(msg)
    image = download_image (url)
    # preprocess
    pre_proc_image=preprocessing_step(image) 
    convert_and_accumulate_to_global_lists(timestamp,pre_proc_image)
    upload_global_lists_to_minio(minio_user="lia-2elavezzi",minio_folder="preproc-store",n_items=200)

# %%
with NATSClient(NATS_SERVER) as client:
    client.subscribe(subject="daq/data/%s" %(username), callback=callback)
    for _ in range(100):
        client.wait(count=200)
# Out:
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:24:49.462656.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:25:29.024378.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:26:10.925214.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:26:51.119421.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:27:34.058601.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:28:15.591637.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:28:54.173838.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:29:33.589919.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:30:10.504129.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T13:30:49.180896.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# ...
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T14:29:45.844106.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T14:30:18.213801.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T14:31:06.144727.npz
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# Status code: 200 [OK]
# UPLOAD lia-2elavezzi 957ba464403d7d86aa1e6d6b7c289da7
# Uploaded preproc-store/data-chunk-2023-10-26T14:31:40.879076.npz
